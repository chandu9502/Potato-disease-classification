# %%
import pickle
from flask import Flask, request, jsonify
from werkzeug.utils import secure_filename
import numpy as np
from io import BytesIO
from PIL import Image
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
MODEL = tf.keras.models.load_model("saved_models/3")

# %%
image = cv2.imread(r'/Users/satwikpuranam/mini_project/alternaria (24).JPG')

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
CLASS_NAMES = ["Early Blight", "Late Blight", "Healthy"]

# %%
image = cv2.resize(image, (256, 256))

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/32/a6/4321f0f30ee11d6d85f49251d417f4e885fe7638b5ac50b7e3c80cccf141/opencv_python-4.8.0.76-cp37-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading opencv_python-4.8.0.76-cp37-abi3-macosx_11_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.21.2 in /opt/homebrew/lib/python3.10/site-packages (from opencv-python) (1.24.3)
# Downloading opencv_python-4.8.0.76-cp37-abi3-macosx_11_0_arm64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:010mm
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.0.76

# %%
img_batch = np.expand_dims(image, 0)

predictions = MODEL.predict(img_batch)

predicted_class = CLASS_NAMES[np.argmax(predictions[0])]
confidence = np.max(predictions[0])
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
predicted_class
# Out:
# 'Early Blight'
