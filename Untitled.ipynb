# %%
import pickle
from flask import Flask, request, jsonify
from werkzeug.utils import secure_filename
import numpy as np
from io import BytesIO
from PIL import Image
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
MODEL = tf.keras.models.load_model("saved_models/3")

# %%
image = cv2.imread(r'C:\Users\Pogula Chandra kanth\OneDrive\Desktop/mini_project/alt.JPG')

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
CLASS_NAMES = ["Early Blight", "Late Blight", "Healthy"]

# %%
image = cv2.resize(image, (256, 256))

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: opencv-python in c:\users\pogula chandra kanth\appdata\roaming\python\python310\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\pogula chandra kanth\appdata\roaming\python\python310\site-packages (from opencv-python) (1.23.3)

# %%
img_batch = np.expand_dims(image, 0)

predictions = MODEL.predict(img_batch)

predicted_class = CLASS_NAMES[np.argmax(predictions[0])]
confidence = np.max(predictions[0])

# %%
predicted_class
# Out:
# 'Healthy'
